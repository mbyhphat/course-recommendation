# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window

# %%
spark = SparkSession.builder \
    .appName("Course-Field") \
    .getOrCreate()

# %% [markdown]
# ## course

# %%
course_df = spark.read.json("/content/drive/MyDrive/Big Data/Input/course.json")

# %%
course_df.show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------+--------+--------------------------------+-------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |about                                                                                                                                                                                                                                                                                                                                                           |field                                 |id      |name                            |prerequisites|resource                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------+--------+--------------------------------+-------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |通过老师导读，同学们可深入这一经典文本内部，得以纵览千年历史，提升国学素养，体味人生智慧。                                                                                                                                                                                                                                                                      |[历史学, 中国语言文学]                |C_584313|《资治通鉴》导读                |             |[{1.1.1, V_849, [第一课 导论与三家分晋, 导论, 导论]}, {1.2.1, V_850, [第一课 导论与三家分晋, 智伯的覆亡, 智伯的覆亡]}, {1.3.1, V_851, [第一课 导论与三家分晋, 智伯悲剧的反思, 智伯的覆亡讨论]}, {1.4, Ex_856, [第一课 导论与三家分晋, NULL, 第一课 导论与三家分晋--习题]}, {2.1.1, V_857, [第二课 战国前期的政治, 魏文侯治国, 魏文侯治国]}, {2.2.1, V_859, [第二课 战国前期的政治, 吴起的悲剧, 吴起的悲剧]}, {2.3.1, V_861, [第二课 战国前期的政治, 魏文侯治国讨论, 魏文侯治国讨论]}, {2.4.1, V_862, [第二课 战国前期的政治, 吴起的悲剧讨论, 吴起的悲剧讨论]}, {2.5, Ex_866, [第二课 战国前期的政治, NULL, 第二课 战国前期的政治--习题]}, {3.1.1, V_867, [第三课 商鞅变法, 背景, 背景]}, {3.2.1, V_868, [第三课 商鞅变法, 过程, 过程]}, {3.3.1, V_869, [第三课 商鞅变法, 商鞅之死, 商鞅之死]}, {3.4.1, V_870, [第三课 商鞅变法, 评论与比较, 评论与比较]}, {3.5.1, V_871, [第三课 商鞅变法, 商鞅变法讨论, 商鞅变法讨论]}, {3.6, Ex_876, [第三课 商鞅变法, NULL, 第三课 商鞅变法--习题]}, {4.1.1, V_877, [第四课 秦国的外交, 南取巴蜀, 南取巴蜀]}, {4.2.1, V_878, [第四课 秦国的外交, 远交近攻, 远交近攻]}, {4.3.1, V_879, [第四课 秦国的外交, 逐客风波, 逐客风波]}, {4.4.1, V_880, [第四课 秦国的外交, 破坏人才, 破坏人才]}, {4.5.1, V_881, [第四课 秦国的外交, 秦国的外交讨论, 秦国的外交讨论]}, {4.6, Ex_882, [第四课 秦国的外交, NULL, 第四课 秦国的外交--习题]}, {5.1.1, V_883, [第五课 千古一帝, 奇货可居（上）, 奇货可居（上）]}, {5.2.1, V_884, [第五课 千古一帝, 奇货可居（下）, 奇货可居（下）]}, {5.3.1, V_885, [第五课 千古一帝, 茅焦之谏, 茅焦之谏]}, {5.4.1, V_886, [第五课 千古一帝, 始皇功过, 始皇功过]}, {5.5.1, V_887, [第五课 千古一帝, 讨论：吕不韦, 讨论：吕不韦]}, {5.6.1, V_888, [第五课 千古一帝, 讨论：李斯, 讨论：李斯]}, {5.7.1, V_889, [第五课 千古一帝, 讨论：赢政, 讨论：赢政]}, {5.8, Ex_890, [第五课 千古一帝, NUL
大帝, NULL, 第九课 汉武大帝--习题]}, {10.1.1, V_917, [第十课  昭宣中兴, 第十课 01昭宣中兴：霍光辅政, 第十课 01昭宣中兴：霍光辅政]}, {10.2.1, V_918, [第十课  昭宣中兴, 第十课 02昭宣中兴：宣帝即位, 第十课 02昭宣中兴：宣帝即位]}, {10.3.1, V_919, [第十课  昭宣中兴, 第十课 03昭宣中兴：霍光之死, 第十课 03昭宣中兴：霍光之死]}, {10.4.1, V_920, [第十课  昭宣中兴, 第十课 04昭宣中兴：祸萌骖乘, 第十课 04昭宣中兴：祸萌骖乘]}, {10.5.1, V_921, [第十课  昭宣中兴, 第十课 昭宣中兴：三人行, 第十课 昭宣中兴：三人行]}, {10.6, Ex_924, [第十课  昭宣中兴, NULL, 第十课 昭宣中兴--习题]}, {11.1.1, V_925, [第十一课 王莽始末, 第十一课 01王莽始末：纯儒起家, 第十一课 01王莽始末：纯儒起家]}, {11.2.1, V_926, [第十一课 王莽始末, 第十一课 02王莽始末：万人拥戴, 第十一课 02王莽始末：万人拥戴]}, {11.3.1, V_927, [第十一课 王莽始末, 第十一课 03王莽始末：新莽建国, 第十一课 03王莽始末：新莽建国]}, {11.4.1, V_928, [第十一课 王莽始末, 第十一课 04王莽始末：王莽末路, 第十一课 04王莽始末：王莽末路]}, {11.5.1, V_929, [第十一课 王莽始末, 第十一课 05王莽始末：三人行, 第十一课 05王莽始末：三人行]}, {11.6, Ex_930, [第十一课 王莽始末, NULL, 第十一课 王莽始末--习题]}, {12.1.1, V_931, [第十二课 光武中兴, 第十二课 01光武中兴：少年大志, 第十二课 01光武中兴：少年大志]}, {12.2.1, V_932, [第十二课 光武中兴 ...
# |本课程是理工科的一门数学基础课，系统、全面地介绍了一元函数微积分学。课程既保持了数学的严谨和抽象的特点，也注意了数学概念的直观和形象的一面。                                                                                                                                                                                                                    |[应用经济学, 数学, 物理学, 理论经济学]|C_584329|微积分——极限理论与一元函数      |             |[{1.1.1, V_1350, [序言, 序言, 序言]}, {2.1.1, V_1351, [第一章 实数与函数, 第一节 实数集的界与确界, 实数集的界]}, {2.1.2, V_1352, [第一章 实数与函数, 第一节 实数集的界与确界, 实数集的确界 ]}, {2.4.1, V_1354, [第一章 实数与函数, 第二节 函数的概念, 函数定义与函数图形]}, {2.4.2, V_1355, [第一章 实数与函数, 第二节 函数的概念, 分段函数与隐函数]}, {2.7.1, V_1357, [第一章 实数与函数, 第三节 函数的运算, 函数的四则运算与复合运算]}, {2.7.2, V_1358, [第一章 实数与函数, 第三节 函数的运算, 函数的反函数]}, {2.10.1, V_1360, [第一章 实数与函数, 第四节 函数的初等性质, 函数的有界性，奇偶性]}, {2.10.2, V_1361, [第一章 实数与函数, 第四节 函数的初等性质, 函数的周期性，单调性]}, {2.10.3, V_1362, [第一章 实数与函数, 第四节 函数的初等性质, 函数的凸性]}, {2.13.1, V_1364, [第一章 实数与函数, 第五节 初等函数, 初等函数]}, {2.16.1, V_1366, [第一章 实数与函数, 第六节 极坐标方程与参数方程表示的几种曲线, 极坐标系与点的极坐标，极坐标方程表示的几种曲线 ]}, {2.16.2, V_1367, [第一章 实数与函数, 第六节 极坐标方程与参数方程表示的几种曲线, 参数方程表示的几种曲线]}, {2.2, Ex_1368, [第一章 实数与函数, NULL, 第一章 实数与函数--第一节思考与练习]}, {2.5, Ex_1369, [第一章 实数与函数, NULL, 第一章 实数与函数--第二节思考与练习]}, {2.8, Ex_1370, [第一章 实数与函数, NULL, 第一章 实数与函数--第三节思考与练习]}, {2.11, Ex_1371, [第一章 实数与函数, NULL, 第一章 实数与函数--第四节思考与练习]}, {2.14, Ex_1372, [第一章 实数与函数, NULL, 第一章 实数与函数--第五节思考与练习]}, {3.1.1, V_1373, [第二章 极限论, 第一节 数列极限的概念与性质, 数列的概念，数列极限的概念（1）]}, {3.1.2, V_1374, [第二章 极限论, 第一节 数列极限的概念与性质, 数列极限的概念（2）]}, {3.1.3, V_1375, [第二章 极限论, 第一节 数列极限的概念与性质, 数列极限的性质及四则运算法则]}, {3.1.4, V_1376, [第二章 极限论, 第一节 数列极限的概念与性质, 无穷大量]}, {3.4.1, V_1378, [第二章 极限论, 第二节 数列极限存在的充分条件, 数列极限存在的充分条件]}, {3.4.2, V_1379, [第二章 极限论, 第二节 数列极限存在的充分条件, 单调有界收敛定理]}, {3.7.1, V_1381, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, Bolzano定理与Cauchy收敛准则]}, {3.7.2, V_1382, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, 区间套定理与Bolzano定理]}, {3.7.3, V_1383, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, Cauchy收敛准则]}, {3.10.1, V_1385, [第二章 极限论, 第四节 函数极限的概念与性质, 函数极限的概念]}, {3.10.2, V_1386, [第二章 极限论, 第四节 函数极限的概念与性质, 函数极限的性质]}, {3.13.1, V_1388, [第二章 极限论, 第五节 函数极限的运算, 函数极限的四则运算与复合函数的极限]}, {3.13.2, V_1389, [第二章 极限论, 第五节 函数极限的运算, 夹逼定理与重要极限]}, {3.16.1, V_1391, [第二章 极限论, 第六节 无穷小量及其（阶的）比较, 无穷小量与无穷大量的概念与性质]}, {3.16.2, V_1392, [第二章 极限论, 第六节 无穷小量及其（阶的）比较, 无穷小量的比较]}, {3.2, Ex_1394, [第二章 极限论, NULL, 第二章 极限论--第一节思考与练习]}, {3.5, Ex_1395, [第二章 极限论, NULL, 第二章 极限论--第二节思考与练习]}, {3.8, Ex_1396, [第二章 极限论, NULL, 第二章 极限论--第三节思考与练习]}, {3.11, Ex_1397, [第二章 极限论, NULL, 第二章 极限论--第四节思考与练习]}, {3.14, Ex_1398, [第二章 极限论, NULL, 第二章 极限论--第五节思考与练习]}, {3.17, Ex_1399, [第二章 极限论, NULL, 第二章 极限论--第六节思考与练习]}, {4.1.1, V_1400, [第三章 连续函数, 第一节 连续函数的概念与性质, 函数在一点连续的概念]}, {4.1.2, V_1401, [第三章 连续函数, 第一节 连续函数的概念与性质, 间断点的分类]}, {4.1.3, V_1402, [第三章 连续函数, 第一节 连续函数的概念与性质, 连续函数的性质]}, {4.1.4, V_1403, [第三章 连续函数, 第一节 连续函数的概念与性质, 连续函数的运算与初等函数的连续性]}, {4.4.1, V_1405, [第三章 连续函数, 第二节 闭区间上连续函数的性质, 闭区间上连续函数的性质]}, {4.7.1, V_1407, [第三章 连续函数, 第三节 函数的一致连续性, 一致连续的概念]}, {4.7.2, V_1408, [第三章 连续函数, 第三节 函数的一致连续性, 一致连续的必要条件]}, {4.7.3, V_1409, [第三章 连续函数, 第三节 函数的一致连续性, 闭区间上连续与一致连续的等价性]}, {4.2, Ex_1411, [第三章 连续函数, NULL, 第三章 连续函数--第一节 思考与练习]}, {4.5, Ex_1412, [第三章 连续函数, NULL, 第三章 连续函数--第二节 思考与练习]}, {4.8, Ex_1413, [第三章 连续函数, NULL, 第三章 连续函数--第三节 思考与练习]}, {5.1.1, V_1414, [第四章 导数与微分, 第一节 导数与微分的概念, 导数的概念]}, {5.1.2, V_1415, [第四章 导数与微分, 第一节 导数与微分的概念, 单侧导数、可导与连续的关系]}, {5.1.3, V_1416, [第四章 导数与微分, 第一节 导数与微分的概念, 导数的几何意义]}, {5.1.4, V_1417, [第四章 导数与微分, 第一节 导数与微分的概念, 微分概念]}, {5.4.1, V_1419, [第四章 导数与微分, 第二节 导数与微分的运算, 导数的四则运算]}, {5.4.2, V_1420, [第四章 导数与微分, 第二节 导数与微分的运算, 复合函数的求导法（链导法则）]}, {5.4.3, V_1421, [第四章 导数与微分, 第二节 导数与微分的运算, 反函数求导法]}, {5.7.1, V_1423, [第四章 导数与微分, 第三节 几种特殊函数的求导法、高阶导数, 几种特殊函数的求导法]}, {5.7.2, V_1424, [第四章 导数与微分, 第三节 几种特殊函数的求导法、高阶导数, 参数方程求导法与对数求导法]}, {5.7.3, V_1425, [第四章 导数与微分, 第三节 几种特殊函数的求导法、高阶导数, 高阶导数]}, {5.2, Ex_1427, [第四章 导数与微分, NULL, 第四章 导数与微分--第一节 思考与练习]}, {5.5, Ex_1428, [第四章 导数与微分, NULL, 第四章 导数与微分--第二节 思考与练习]}, {5.8, Ex_1429, [第四章 导数与微分, NULL, 第四章 导数与微分--第三节 思考与练习]}, {6.1.1, V_1430, [第五章 导数应用, 第一节 微分中值定理, Fermat定理]}, {6.1.2, V_1431, [第五章 导数应用, 第一节 微分中值定理, Rolle定理]}, {6 ...
# |掌握基本的摄影技能，了解图片新闻的工作方式，训练对生活的观察和热爱，发展对图像的审美和批评能力，以及，培养一个终身的爱好。                                                                                                                                                                                                                                      |[艺术学, 新闻传播学]                  |C_584381|新闻摄影                        |             |[{1.1.1, V_1800, [第一章 绪论, 第一讲 引言1, 引言1]}, {1.2.1, V_1801, [第一章 绪论, 第二讲 引言2, 引言2]}, {1.3.1, V_1802, [第一章 绪论, 第三讲 认识照相机, 认识照相机]}, {1.4.1, V_1803, [第一章 绪论, 第四讲 从镜头说起, 从镜头说起]
字图片后期, 新闻摄影后期准则, 新闻摄影后期准则]}, {6.2.1, V_1837, [第四章 数字图片后期, 数码照片处理（1）, 数码照片处理（1）]}, {6.3.1, V_1838, [第四章 数字图片后期, 数码照片处理（2）, 数码照片处理（2）]}, {6.4.1, V_1839, [第四章 数字图片后期, 位图与矢量图, 位图与矢量图]}, {6.5.1, V_1840, [第四章 数字图片后期, RAW与JPG, RAW与JPG]}, {6.6.1, V_1841, [第四章 数字图片后期, 后期基础, 后期基础]}, {6.7.1, V_1842, [第四章 数字图片后期, PS入门, PS入门]}, {6.8.1, V_1843, [第四章 数字图片后期, Lr入门, Lr入门]}, {6.9, Ex_1844, [第四章 数字图片后期, NULL, 第四章 数字图片后期--练习题]}, {7.1.1, V_1845, [第五章 摄影曝光, 光线与影调, 光线与影调]}, {7.2.1, V_1846, [第五章 摄影曝光, 曝光和测光, 曝光与测光]}, {7.3.1, V_1847, [第五章 摄影曝光, 测光模式, 测光模式]}, {7.4.1, V_1848, [第五章 摄影曝光, 测光模式演示, 测光模式演示]}, {7.5.1, V_1849, [第五章 摄影曝光, 曝光的标准, 曝光的标准]}, {7.6.1, V_1850, [第五章 摄影曝光, 曝光补偿与包围曝光, 曝光补偿与包围曝光]}, {7.7.1, V_1851, [第五章 摄影曝光, 分区曝光法（1）, 分区曝光法（1）]}, {7.8.1, V_1852, [第五章 摄影曝光, 分区曝光法（2）, 分区曝光法（2）]}, {7.9.1, V_1853, [第五章 摄影曝光, 高调与低调, 高调与低调]}, {7.10.1, V_1854, [第五章 摄影曝光, 应用与总结, 应用与总结]}, {8.1.1, V_1855, [答疑视频3, 答疑视频3, 答疑视频3]}, {9.1.1, V_1856, [答疑视频4, 答疑视频4, 答疑视频4]}, {10.1.1, V_1857, [第六章 摄影构图, 构图引言, 构图引言]}, {10.2.1, V_1858, [第六章 摄影构图, 立体感, 立体感]}, {10.3.1, V_1859, [第六章 摄影构图, 质感, 质感]}, {10.4.1, V_1860, [第六章 摄影构图, 空间感, 空间感]}, {10.5.1, V_1861, [第六章 摄影构图, 构图的三项标准, 构图的三项标准]}, {10.6.1, V_1862, [第六章 摄影构图, 构图的五种基本规律, 构图的五种基本规律]}, {10.7.1, V_1863, [第六章 摄影构图, 构图要素：主体, 构图要素-主体]}, {10.8.1, V_1864, [第六章 摄影构图, 构图要素：陪体, 构图要素：陪体]}, {10.9.1, V_1865, [第六章 摄影构图, 构图要素：前景, 构图要素：前景]}, {10.10.1, V_1866, [第六章 摄影构图, 构图要素：背景, 构图要素：背景]}, {10.11.1, V_1867, [第六章 摄影构图, 构图要素：留白, 构图要素：留白]}, {10.12.1, V_1868, [第六章 摄影构图, 拍摄角度：景别, 拍摄角度：景别]}, {10.13.1, V_1869, [第六章 摄影构图, 拍摄角度：角度, 拍摄角度：角度]}, {10.14.1, V_1870, [第六章 摄影构图, 拍摄角度：高度, 拍摄角度：高度]}, {10.15.1, V_1871, [第六章 摄影构图, 构图部分总结, 构图部分总结]}, {11.1.1, V_1872, [答疑视频5, 答疑视频5, 答疑视频5]}, {12.1.1, V_1873, [第七章 光线, 光线造型, 光线造型]}, {12.2.1, V_1874, [第七章 光线, 主光, 主光]}, {12.3.1, V_1875, [第七章 光线, 各类辅助光, 各类辅助光]}, {12.4.1, V_1876,  ...
# |最有趣的理论+最有用的算法=不得不学的数据科学。                                                                                                                                                                                                                                                                                                                  |[计算机科学与技术]                    |C_597208|数据挖掘：理论与算法            |             |[{1.1.1, V_2961, [走进数据科学：博大精深，美不胜收, 整装待发, Video]}, {1.3.1, V_2962, [走进数据科学：博大精深，美不胜收, 学而不思则罔, Video]}, {1.5.1, V_2963, [走进数据科学：博大精深，美不胜收, 知行合一, Video]}, {1.7.1, V_2964, [走进数据科学：博大精深，美不胜收, 从数据到知识, Video]}, {1.9.1, V_2965, [走进数据科学：博大精深，美不胜收, 分类问题, Video]}, {1.11.1, V_2966, [走进数据科学：博大精深，美不胜收, 聚类及其它数据挖掘问题, Video]}, {1.13.1, V_2967, [走进数据科学：博大精深，美不胜收, 隐私保护与并行计算, Video]}, {1.15.1, V_2968, [走进数据科学：博大精深，美不胜收, 迷雾重重, Video]}, {1.16.1, V_2969, [走进数据科学：博大精深，美不胜收, 相关学习资源, 视频来源：互联网]}, {1.2, Ex_2972, [走进数据科学：博大精深，美不胜收, NULL, 第一章第二节测试题]}, {1.4, Ex_2973, [走进数据科学：博大精深，美不胜收, NULL, 第一章第三节测试题]}, {1.6, Ex_2974, [走进数据科学：博大精深，美不胜收, NULL, 第一章第四节测试题]}, {1.8, Ex_2975, [走进数据科学：博大精深，美不胜收, NULL, 第一章第五节测试题]}, {1.10, Ex_2976, [走进数据科学：博大精深，美不胜收, NULL, 第一章第六节测试题]}, {1.12, Ex_2977, [走进数据科学：博大精深，美不胜收, NULL, 第一章第七节测试题]}, {1.14, Ex_2978, [走进数据科学：博大精深，美不胜收, NULL, 第一章第八节测试题]}, {2.2.1, V_2979, [数据预处理：抽丝剥茧，去伪存真, 数据清洗, Video]}, {2.4.1, V_2980, [数据预处理：抽丝剥茧，去伪存真, 异常值与重复数据检测, Video]}, {2.6.1, V_2981, [数据预处理：抽丝剥茧，去伪存真, 类型转换与采样, Video]}, {2.8.1, V_2982, [数据预处理：抽丝剥茧，去伪存真, 数据描述与可视化, Video]}, {2.10.1, V_2983, [数据预处理：抽丝剥茧，去伪存真, 特征选择, Video]}, {2.12.1, V_2984, [数据预处理：抽丝剥茧，去伪存真, 主成分分析, Video]}, {2.14.1, V_2985, [数据预处理：抽丝剥茧，去伪存真, 线性判别分析, Video]}, {2.14.2, V_2986, [数据预处理：抽丝剥茧，去伪存真, 线性判别分析, Video]}, {2.15.1, V_2987, [数据预处理：抽丝剥茧，去伪存真, 相关学习资源, 视频来源：互联网]}, {2.1, Ex_2990, [数据预处理：抽丝剥茧，去伪存真, NULL, 第二章第一节测试题]}, {2.3, Ex_2991, [数据预处理：抽丝剥茧，去伪存真, NULL, 第二章第二节测试题]}, {2.5, Ex_2
巅峰之作, NULL, 第五章第一节测试题]}, {5.3, Ex_3030, [支持向量机：数学之美，巅峰之作, NULL, 第五章第二节测试题]}, {5.5, Ex_3031, [支持向量机：数学之美，巅峰之作, NULL, 第五章第三节测试题]}, {5.7, Ex_3032, [支持向量机：数学之美，巅峰之作, NULL, 第五章第四节测试题]}, {6.2.1, V_3033, [聚类分析：物以类聚，人以群分, 无监督学习, Video]}, {6.4.1, V_3034, [聚类分析：物以类聚，人以群分, K-Means, Video]}, {6.6.1, V_3035, [聚类分析：物以类聚，人以群分, 期望最大法, Video]}, {6.8.1, V_3036, [聚类分析：物以类聚，人以群分, 密度与层次, Video]}, {6.1, Ex_3040, [聚类分析：物以类聚，人以群分, NULL, 第六章第一节测试题]}, {6.3, Ex_3041, [聚类分析：物以类聚，人以群分, NULL, 第六章第二节测试题]}, {6.5, Ex_3042, [聚类分析：物以类聚，人以 ...
# |大学计算机课程将以计算思维为导向，以计算机原理、概念为基础，以新技术新方法为牵引，以创新思维能力培养为目标，和学习者一起了解计算机科学，学习计算技术，掌握思维方法。                                                                                                                                                                                            |[]                                    |C_597225|大学计算机                      |             |[{1.1.1, V_4596, [第1周： 基于计算机的问题求解, 课程介绍, 开篇]}, {1.2.1, V_4597, [第1周： 基于计算机的问题求解, 1.0 本章导学, 1.0 本章导学]}, {1.3.1, V_4598, [第1周： 基于计算机的问题求解, 1.1 基于计算机的问题求解方法, 1.1.1 基于计算机软件的问题求解方法]}, {1.3.2, V_4599, [第1周： 基于计算机的问题求解, 1.1 基于计算机的问题求解方法, 1.1.2 基于计算机程序的问题求解方法]}, {1.3.3, V_4600, [第1周： 基于计算机的问题求解, 1.1 基于计算机的问题求解方法, 1.1.3 基于系统的工程问题求解方法]}, {1.5.1, V_4603, [第1周： 基于计算机的问题求解, 1.2 问题描述与抽象, 1.2.1 问题描述与抽象]}, {1.5.2, V_4604, [第1周： 基于计算机的问题求解, 1.2 问题描述与抽象, 1.2.2 面向计算机的问题分析]}, {1.6.1, V_4607, [第1周： 基于计算机的问题求解, 1.3 计算机科学学科的知识领域, 1.3 计算机科学的知识领域]}, {1.8.1, V_4610, [第1周： 基于计算机的问题求解, 虚拟实验——图灵机模型与计算机硬件系统虚拟拆装, 实验]}, {1.9.1, V_4611, [第1周： 基于计算机的问题求解, 知识扩展——揭秘北京2008奥运会活字印刷的表演设计, 活字印刷]}, {1.4, Ex_4612, [第1周： 基于计算机的问题求解, NULL, 1.1作业]}, {1.7, Ex_4613, [第1周： 基于计算机的问题求解, NULL, 1.2作业]}, {1.10, Ex_4614, [第1周： 基于计算机的问题求解, NULL, 1.3作业]}, {1.12, Ex_4615, [第1周： 基于计算机的问题求解, NULL, 第一周测试]}, {2.1.1, V_4616, [第2周：计算机信息数字化基础, 2.0 本章导学, 2.0 本章导学]}, {2.2.1, V_4617, [第2周：计算机信息数字化基础, 2.1 数制及其在计算机中的表示, 2.1.1 八卦图与二进制]}, {2.2.2, V_4618, [第2周：计算机信息数字化基础, 2.1 数制及其在计算机中的表示, 2.1.2 计算机中各种数制的表示]}, {2.2.3, V_4619, [第2周：计算机信息数字化基础, 2.1 数制及其在计算机中的表示, 2.1.3 不同数制之间的转换A]}, {2.2.4, V_4620, [第2周：计算机信息数字化基础, 2.1 数制及其在计算机中的表示, 2.1.3 不同数制之间的转换B]}, {2.4.1, V_4623, [第2周：计算机信息数字化基础, 2.2 二进制数据计算, 2.2.1 1 机器数、真值与模]}, {2.4.2, V_4624, [第2周：计算机信息数字化基础, 2.2 二进制数据计算, 2.2.1 2 原码、反码和补码]}, {2.4.3, V_4625, [第2周：计算机信息数字化基础, 2.2 二进制数据计算, 2.2.1 3 数值的定点表示和浮点表示]}, {2.4.4, V_4626, [第2周：计算机信息数字化基础, 2.2 二进制数据计算, 2.2.2 算术运算与补码]}, {2.4.5, V_4627, [第2周：计算机信息数字化基础, 2.2 二进制数据计算, 2.2.3 逻辑运算与计算机控制]}, {2.5.1, V_4631, [第2周：计算机信息数字化基础, 2.3 字符信息编码与标准交换, 2.3.1 西文字符的编码与标准交换]}, {2.5.2, V_4632, [第2周：计算机信息数字化基础, 2.3 字符信息编码与标准交换, 2.3.2 汉字信息的编码与交换]}, {2.5.3, V_4633, [第2周：计算机信息数字化基础, 2.3 字符信息编码与标准交换, 2.3.3 通用字符编码集UCS]}, {2.7.1, V_4636, [第2周：计算机信息数字化基础, 2.4 多媒体信息编码, 2.4.1 图形图像信息数字化]}, {2.7.2, V_4637, [第2周：计算机信息数字化基础, 2.4 多媒体信息编码, 2.4.2 声音信息数字化]}, {2.7.3, V_4638, [第2周：计算机信息数字化基础, 2.4 多媒体信息编码, 2.4.3 颜色信息数字化]}, {2.8.1, V_4641, [第2周：计算机信息数字化基础, 知识扩展——扫一扫，扫出了什么？, 扫一扫，扫出了什么]}, {2.10.1, V_4642, [第2周：计算机信息数字化基础, 虚拟实验——字符编码与信息交换, 虚拟实验——字符编码与信息交换]}, {2.3, Ex_4643, [第2周：计算机信息数字化基础, NULL, 2.1作业]}, {2.6, Ex_4644, [第2周：计算机信息数字化基础, NULL, 2.2作业]}, {2.9, Ex_4645, [第2周：计算机信息数字化基础, NULL, 2.3作业]}, {2.12, Ex_4646, [第2周：计算机信息数字化基础, NULL, 2.4作业]}, {2.13, Ex_4647, [第2周：计算机信息数字化基础, NULL, 第二周测试]}, {3.1.1, V_4648, [百家视点, 百家视点, 从二进制起源窥见的奥秘]}, {3.1.2, V_4649, [百家视点, 百家视点, 谷歌背后的技术]}, {3.1.3, V_4650, [百家视点, 百家视点, 你真的了解计算机存储器吗]}, {3.1.4, V_4651, [百家视点, 百家视点, 关于大数据]}, {3.1.5, V_4652, [百家视点, 百家视点, 为何说计算机只会做加法]}, {3.1.6, V_4653, [百家视点, 百家视点, 图灵机的一个例子]}, {4.1.1, V_4654, [第3周：计算机的工作原理与硬件体系结构, 3.0 本章导学, 3.0 本章导学]}, {4.2.1, V_4655, [第3周：计算机的工作原理与硬件体系结构, 3.1 计算机如何完成加法运算, 3.1.1 计算工具的演变]}, {4.2.2, V_4656, [第3周：计算机的工作原理与硬件体系结构, 3.1 计算机如何完成加法运算, 3.1.2 算数逻辑单元]}, {4.2.3, V_4657, [第3周：计算机的工作原理与硬件体系结构, 3.1 计算机如何完成加法运算, 3.1.3 存储器与寻址]}, {4.4.1, V_4660, [第3周：计算机的工作原理与硬件体系结构, 3.2 冯诺依曼体系结构, 3.2.1 机器指令]}, {4.4.2, V_4661, [第3周：计算机的工作原理与硬件体系结构, 3.2 冯诺依曼体系结构, 3.2.2 加法指令实现原理]}, {4.4.3, V_4662, [第3周：计算机的工作原理与硬件体系结构, 3.2 冯诺依曼体系结构, 3.2.3 冯诺依曼结构]}, {4.5.1, V_4665, [第3周：计算机的工作原理与硬件体系结构, 3.3 计算机硬件及其连接, 3.3.1 中央处理器]}, {4.5.2, V_4666, [第3周：计算机的工作原理与硬件体系结构, 3.3 计算机硬件及其连接, 3.3.2 多级存储结构]}, {4.5.3, V_4667, [第3周：计算机的工作原理与硬件体系结构, 3.3 计算机硬件及其连接, 3.3.3 主板输入输出]}, {4.5.4, V_4668, [第3周：计算机的工作原理与硬件体系结构, 3.3 计算机硬件及其连接, 3.3.4 计算机硬件及组装演示]}, {4.7.1, V_4671, [第3周：计算机的工作原理与硬件体系结构, 3.4 图灵机, 3.4.1 图灵及图灵机]}, {4.7.2, V_4672, [第3周：计算机的工作原理与硬件体系结构, 3.4 图灵机, 3.4.2 本章小结]}, {4.8.1, V_4674, [第3周：计算机的工作原理与硬件体系结构, 虚拟实验——一条指令执行过程, Video]}, {4.10.1, V_4675, [第3周：计算机的工作原理与硬件体系结构, 知识扩展——可穿戴的计算设备, 可穿戴计算]}, {4.3, Ex_4676, [第3周：计算机的工作原理与硬件体系结构, NULL, 3.1作业]}, {4.6, Ex_4677, [第3周：计算机的 ...
# |这门课程用财务语言解构企业的价值创造过程，从而帮助学习者理解影响价值创造的各种因素，建立财务思维，并具备将其应用于商业决策的能力。                                                                                                                                                                                                                              |[应用经济学, 管理科学与工程]          |C_597229|财务分析与决策                  |             |[{2.1.1, V_5042, [资金的运用——认识资产, 1.1 绪论, 绪论]}, {2.2.1, V_5043, [资金的运用——认识资产, 1.2 认识资产负债表, 认识资产负债表]}, {2.3.1, V_5044, [资金的运用——认识资产, 1.3 资产的概念, 资产的概念]}, {2.4.1, V_5045, [资金的运用——认识资产, 1.4 资产的结构, 资产的结构]}, {2.5.1, V_5046, [资金的运用——认识资产, 1.5 资产的价值, 资产的价值]}, {2.6, Ex_5048, [资金的运用——认识资产, NULL, 资金的运用——认识资产--1.6 习题]}, {3.1.1, V_5049, [资金的来源与利润的产生, 肖老师来啦~~o(≧v≦)o~~好棒, 肖老师来啦！]}, {3.2.1, V_5050, [资金的来源与利润的产生, 2.1 认识负债, 认识负债]}, {3.3.1, V_5051, [资金的来源与利润的产生, 2.2 股东的权益, 股东的权益]}, {3.4.1, V_5052, [资金的来源与利润的产生, 2.3 资产负债表总结, 资产负债表总结]}, {3.5.1, V_5053, [资金的来源与利润的产生, 2.4 认识利润表, 认识利润表]}, {3.6.1, V_5054, [资金的来源与利润的产生, 2.5 利润表总结, 利润表总结]}, {3.7, Ex_5056, [资金的来源与利润的产生, NULL, 资金的来源与利润的产生--2.6 习题]}, {4.1.1, V_5057, [财务报表是如何产生的, 肖老师邀你来听课啦~, 默认]}, {4.2.1, V_5058, [财务报表是如何产生的, 3.1 企业设立、筹建中的经济活动与财务报表, 3.1 企业设立、筹建中的经济活动与财务报表]}, {4.3.1, V_5059, [财务报表是如何产生的, 3.2 采购生产环节的经济活动与财务报表, 3.2 采购生产环节的经济活动与财务报表]}, {4.5.1, V_5060, [财务报表是如何产生的, 3.3 产量、销量与毛利润, 3.3 产量、销量与毛利润]}, {4.6.1, V_5061, [财务报表是如何产生的, 3.4 销售环节的经济活动与财务报表, 3.4 销售环节的经济活动与财务报表]}, {4.7.1, V_5062, [财务报表是如何产生的, 3.5 费用支付、研发活动与财务报表, 3.5 费用支付、研发活动与财务报表]}, {4.9.1, V_5063, [财务报表是如何产生的, 3.6 所得税、利润、利润分配与财务报表, 3.6 所得税、利润、利润分配与财务报表]}, {4.4, Ex_5065, [财务报表是如何产生的, NULL, 财务报表是如何产生的--3.2 采购生产环节的经济活动与财务报表]}, {4.8, Ex_5066, [财务报表是如何产生的, NULL, 财务报表是如何产生的--3.3 产量、销量与毛利润]}, {4.10, Ex_5067, [财务报表是如何产生的, NULL, 财务报表是如何产生的--3.5 费用支付、研发活动与财务报表]}, {4.12, Ex_5068, [财务报表是如何产生的, NULL, 财务报表是如何产生的--3.4 销售环节的经济活动与财务报表]}, {4.13, Ex_5069, [财务报表是如何产生的, NULL, 财务报表是如何产生的--3.7 习题]}, {5.1.1, V_5070, [财务报表的逻辑架构, 肖老师每周与你不见不散！, 3月30日]}, {5.2.1, V_5071, [财务报表的逻辑架构, 4.1 资产负债表和利润表的关系, 4.1 资产负债表和利润表的关系]}, {5.4.1, V_5072, [财务报表的逻辑架构, 4.2 认识现金流量表, 4.2 认识现金流量表]}, {5.5.1, V_5073, [财务报表的逻辑架构, 4.3 现金流量表的作用, 4.3 现金流量表的作用]}, {5.7.1, V_5074, [财务报表的逻辑架构, 4.4 现金流量表是如何产生的？, 4.4 现金流量表是如何产生的？]}, {5.8.1, V_5075, [财务报表的逻辑架构, 4.5 三张报表的逻辑关系, 4.5 三张报表的逻辑关系]}, {5.10.1, V_5076, [财务报表的逻辑架构, 4.6 三张报表的角色分别是什么？, 4.6 三张报表的角色分别是什么？]}, {5.3, Ex_5078, [财务报表的逻辑架构, NULL, 财务报表的逻辑架构--4.1 资产负债表和利润表的关系]}, {5.6, Ex_5079, [财务报表的逻辑架构, NULL, 财务报表的逻辑架构--4.2 认识现金流量表]}, {5.9, Ex_5080, [财务报表的逻辑架构, NULL, 财务报表的逻辑架构--4.3 现金流量表的作用]}, {5.11, Ex_5081, [财务报表的逻辑架构, NULL, 财务报表的逻辑架构--4.4 现金流量表是如何产生的？]}, {5.13, Ex_5082, [财务报表的逻辑架构, NULL, 财务报表的逻辑架构--4.7 习题]}, {6.1.1, V_5083, [财务分析的基本方法, 5.1 同型分析, 5.1 同型分析]}, {6.2.1, V_5084, [财务分析的基本方法, 5.2 盈利能力分析, 5.2 盈利能力分析]}, {6.4.1, V_5085, [财务分析的基本方法, 5.3 营运能力分析, 5.3 营运能力分析]}, {6.5.1, V_5086, [财务分析的基本方法, 5.4 短期偿债能力分析, 5.4短期偿债能力分析]}, {6.7.1, V_5087, [财务分析的基本方法, 5.5 长期偿债能力分析, 5.5长期偿债能力分析]}, {6.3, Ex_5089, [财务分析的基本方法, NULL, 财务分析的基本方法--5.2 盈利能力分析]}, {6.6, Ex_5090, [财务分析的基本方法, NULL, 财务分析的基本方法--5.3 营运能力分析]}, {6.8, Ex_5091, [财务分析的基本方法, NULL, 财务分析的基本方法--5.4 短期偿债能力分析]}, {6.10, Ex_5092, [财务分析的基本方法, NULL, 财务分析的基本方法--5.5 长期偿债能力分析]}, {6.11, Ex_5093, [财务分析的基本方法, NULL, 财务分析的基本方法--5.6 习题]}, {7.1.1, V_5094, [业务、战略与财务数据, 6.1 影响财务数据的因素, 6.1 影响财务数据的因素]}, {7.3.1, V_5095, [业务、战略与财务数据, 6.2 造纸行业与家电行业简介, 6.2 造纸行业与家电行业简介]}, {7.4.1, V_5096, [业务、战略与财务数据, 6.3 财务数据与行业特征——造纸行业与家电行业的对比, 6.3 财务数据与行业特征——造纸行业与家电行业的对比]}, {7.5.1, V_5097, [业务、战略与财务数据, 6.4 财务数据与行业特征——造纸行业的纵向分析, 6.4 财务数据与行业特征——造纸行业的纵向分析]}, {7.6.1, V_5098, [业务、战略与财务数据, 6.5 财务数据与行业特征——家电行业的纵向分析, 6.5 财务数据与行业特征——家电行业的纵向分析]}, {7.8.1, V_5099, [业务、战略与财务数据, 6.6 财务数据与竞争战略, 6.6 财务数据与竞争战略]}, {7.2, Ex_5101, [业务、战略与财务数据, NULL, 业务、战略与财务数据--6.1 影响财务数据的因素]}, {7.7, Ex_5102, [业务、战略与财务数据, NULL, 业务、战略与财务数据--6.4 财务数据与行业特征——造纸行业的纵向分析]}, {7.9, Ex_5103, [业务、战略与财务数据, NULL, 业务、战略与财务数据--6.5 财务数据与行业特征——家电行业的纵向分析]}, {7.11, Ex_5104, [业务、战略与财务数据, NULL, 业务、战略与财务数据--6.6 财务数据与竞争战略]}, {7.12, Ex_5105, [业务、战略与财务数据, NULL, 业务、战略与财务数据--6.7 习题]}, {8.1.1, V_5106, [财务分析的目标——好企业是什么样的, 7.1 好企业是什么样的？, 7.1 好企业是什么样的？]}, {8.3.1, V_5107,  ...
�宗即位, 第三节 宪宗即位]}, {10.4.1, V_9451, [第十课、改革困境, 第四节 元和中兴, 第四节 元和中兴]}, {10.5.1, V_9452, [第十课、改革困境, 第五节 宦官专权, 第五节 宦官专权]}, {10.7, Ex_9454, [第十课、改革困境, NULL, 第十课、改革困境--习题]}, {11.1.1, V_9455, [第十一课、晚唐政局, 第一节 肘腋之仇, 第一节 肘腋之仇]}, {11.2.1, V_9456, [第十一课、晚唐政局, 第二节 甘露之变, 第二节 甘露之变]}, {11.3.1, V_9457, [第十一课、晚唐政局, 第三节 朋党之争, 第三节 朋党之争]}, {11.4.1, V_9458, [第十一课、晚唐政局, 第四节 会昌之政, 第四节 会昌之政]}, {11.5, Ex_9459, [第十一课、晚唐政局, NULL, 第十一课、晚唐政局--习题]}, {12.1.1, V_9460, [第十二课、落日长安, 第一节 宣宗家教, 第一节 宣宗家教]}, {12.2.1, V_9461, [第十二课、落日长安, 第二节 大中之政, 第二节 大中之政]}, {12.3.1, V_9462, [第十二课、落日长安, 第三节 唐朝灭亡, 第三节 唐朝灭亡]}, {12.4.1, V_9463, [第十二课、落日长安, 第四节 五代残唐, 第四节 五代残唐]}, {12.5, Ex_9464, [第十二课、落日长安, NULL, 第十二课、落日长安--习题]}]                                                                                                                                                                                                                                                                                                                                                                                                 ...
# ...
# |这里是商品简介                                                                                                                                                                                                                                                                                                                                                  |[]                                    |C_654397|测试系列课0710_1                |             |[{1.1.1, V_30728, [第一章：界面设计概述, 1.1小节, 视频1]}, {1.1.4, Ex_30731, [第一章：界面设计概述, 1.1小节, 作业1]}, {2.1, V_30732, [第二章：GUI设计心法, NULL, 视频2]}, {2.2, V_30733, [第二章：GUI设计心法, NULL, 视频3]}, {2.5, Ex_30736, [第二章：GUI设计心法, NULL, 作业2]}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |本课程是界面设计的入门课，面向初学者，通过全面介绍界面设计领域的发展现状、应用领域和趋势，帮助学生建立一个较完整的知识框架，丰富视野，并从GUI和H5网页设计与制作方法这两个知识点入手，循序渐进地教学生学做简单的网页GUI设计，体验一个完整的设计过程，学生通过这种带有实践性的学习体验，可以对界面设计有一个初步的认识和了解，为将来的深入学习和自我提高做好铺垫。|[]                                    |C_654551|系列课测试4-zm                  |             |[{1.1.1, V_31077, [序言, 序言, 序言]}, {1.1.1, V_31273, [序言, 序言, 序言]}, {2.1.1, V_31274, [第一章 实数与函数, 第一节 实数集的界与确界, 实数集的界]}, {2.1.1, V_31078, [第一章 实数与函数, 第一节 实数集的界与确界, 实数集的界]}, {2.1.2, V_31275, [第一章 实数与函数, 第一节 实数集的界与确界, 实数集的确界 ]}, {2.1.2, V_31079, [第一章 实数与函数, 第一节 实数集的界与确界, 实数集的确界 ]}, {2.4.1, V_31081, [第一章 实数与函数, 第二节 函数的概念, 函数定义与函数图形]}, {2.4.1, V_31277, [第一章 实数与函数, 第二节 函数的概念, 函数定义与函数图形]}, {2.4.2, V_31082, [第一章 实数与函数, 第二节 函数的概念, 分段函数与隐函数]}, {2.4.2, V_31278, [第一章 实数与函数, 第二节 函数的概念, 分段函数与隐函数]}, {2.7.1, V_31280, [第一章 实数与函数, 第三节 函数的运算, 函数的四则运算与复合运算]}, {2.7.1, V_31084, [第一章 实数与函数, 第三节 函数的运算, 函数的四则运算与复合运算]}, {2.7.2, V_31281, [第一章 实数与函数, 第三节 函数的运算, 函数的反函数]}, {2.7.2, V_31085, [第一章 实数与函数, 第三节 函数的运算, 函数的反函数]}, {2.10.1, V_31087, [第一章 实数与函数, 第四节 函数的初等性质, 函数的有界性，奇偶性]}, {2.10.1, V_31283, [第一章 实数与函数, 第四节 函数的初等性质, 函数的有界性，奇偶性]}, {2.10.2, V_31284, [第一章 实数与函数, 第四节 函数的初等性质, 函数的周期性，单调性]}, {2.10.2, V_31088, [第一章 实数与函数, 第四节 函数的初等性质, 函数的周期性，单调性]}, {2.10.3, V_31285, [第一章 实数与函数, 第四节 函数的初等性质, 函数的凸性]}, {2.10.3, V_31089, [第一章 实数与函数, 第四节 函数的初等性质, 函数的凸性]}, {2.13.1, V_31091, [第一章 实数与函数, 第五节 初等函数, 初等函数]}, {2.13.1, V_31287, [第一章 实数与函数, 第五节 初等函数, 初等函数]}, {2.16.1, V_31093, [第一章 实数与函数, 第六节 极坐标方程与参数方程表示的几种曲线, 极坐标系与点的极坐标，极坐标方程表示的几种曲线 ]}, {2.16.1, V_31289, [第一章 实数与函数, 第六节 极坐标方程与参数方程表示的几种曲线, 极坐标系与点的极坐标，极坐标方程表示的几种曲线 ]}, {2.16.2, V_31094, [第一章 实数与函数, 第六节 极坐标方程与参数方程表示的几种曲线, 参数方程表示的几种曲线]}, {2.16.2, V_31290, [第一章 实数与函数, 第六节 极坐标方程与参数方程表示的几种曲线, 参数方程表示的几种曲线]}, {2.2, Ex_31291, [第一章 实数与函数, NULL, 第一章 实数与函数--第一节思考与练习]}, {2.2, Ex_31095, [第一章 实数与函数, NULL, 第一章 实数与函数--第一节思考与练习]}, {2.5, Ex_31096, [第一章 实数与函数, NULL, 第一章 实数与函数--第二节思考与练习]}, {2.5, Ex_31292, [第一章 实数与函数, NULL, 第一章 实数与函数--第二节思考与练习]}, {2.8, Ex_31097, [第一章 实数与函数, NULL, 第一章 实数与函数--第三节思考与练习]}, {2.8, Ex_31293, [第一章 实数与函数, NULL, 第一章 实数与函数--第三节思考与练习]}, {2.11, Ex_31294, [第一章 实数与函数, NULL, 第一章 实数与函数--第四节思考与练习]}, {2.11, Ex_31098, [第一章 实数与函数, NULL, 第一章 实数与函数--第四节思考与练习]}, {2.14, Ex_31099, [第一章 实数与函数, NULL, 第一章 实数与函数--第五节思考与练习]}, {2.14, Ex_31295, [第一章 实数与函数, NULL, 第一章 实数与函数--第五节思考与练习]}, {3.1.1, V_31296, [第二章 极限论, 第一节 数列极限的概念与性质, 数列的概念，数列极限的概念（1）]}, {3.1.1, V_31100, [第二章 极限论, 第一节 数列极限的概念与性质, 数列的概念，数列极限的概念（1）]}, {3.1.2, V_31297, [第二章 极限论, 第一节 数列极限的概念与性质, 数列极限的概念（2）]}, {3.1.2, V_31101, [第二章 极限论, 第一节 数列极限的概念与性质, 数列极限的概念（2）]}, {3.1.3, V_31102, [第二章 极限论, 第一节 数列极限的概念与性质, 数列极限的性质及四则运算法则]}, {3.1.3, V_31298, [第二章 极限论, 第一节 数列极限的概念与性质, 数列极限的性质及四则运算法则]}, {3.1.4, V_31103, [第二章 极限论, 第一节 数列极限的概念与性质, 无穷大量]}, {3.1.4, V_31299, [第二章 极限论, 第一节 数列极限的概念与性质, 无穷大量]}, {3.4.1, V_31105, [第二章 极限论, 第二节 数列极限存在的充分条件, 数列极限存在的充分条件]}, {3.4.1, V_31301, [第二章 极限论, 第二节 数列极限存在的充分条件, 数列极限存在的充分条件]}, {3.4.2, V_31302, [第二章 极限论, 第二节 数列极限存在的充分条件, 单调有界收敛定理]}, {3.4.2, V_31106, [第二章 极限论, 第二节 数列极限存在的充分条件, 单调有界收敛定理]}, {3.7.1, V_31108, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, Bolzano定理与Cauchy收敛准则]}, {3.7.1, V_31304, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, Bolzano定理与Cauchy收敛准则]}, {3.7.2, V_31305, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, 区间套定理与Bolzano定理]}, {3.7.2, V_31109, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, 区间套定理与Bolzano定理]}, {3.7.3, V_31306, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, Cauchy收敛准则]}, {3.7.3, V_31110, [第二章 极限论, 第三节 Bolzano定理与Cauchy收敛准则, Cauchy收敛准则]}, {3.10.1, V_31308, [第二章 极限论, 第四节 函数极限的概念与性质, 函数极限的概念]}, {3.10.1, V_31112, [第二章 极限论, 第四节 函数极限的概念与性质, 函数极限的概念]}, {3.10.2, V_31309, [第二章 极限论, 第四节 函数极限的概念与性质, 函数极限的性质]}, {3.10.2, V_31113, [第二章 极限论, 第四节 函数极限的概念与性质, 函数极限的性质]}, {3.13.1, V_31115, [第二章 极限论, 第五节 函数极限的运算, 函数极限的四则运算与复合函数的极限]}, {3.13.1, V_31311, [第二章 极限论, 第五节 函数极限的运算, 函数极限的四则运算与复合函数的极限]}, {3.13.2, V_31116, [第二章 极限论, 第五节 函数极限的运算, 夹逼定理与重要极限]}, {3.13.2, V_31312, [第二章 极限论, 第五节 函数极限的运算, 夹逼定理与重要极限]}, {3.16.1, V_31314, [第二章 极限论, 第六节 无穷小量及其（阶的）比较, 无穷小量与无穷大量的概念与性质]}, {3.16.1, V_31118, [第二章 极限论, 第六节 无穷小量及其（阶的）比较, 无穷小量与无穷大量的概念与性质]}, {3.16.2, V_31119, [第二 ...
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------+--------+--------------------------------+-------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
course_df.describe().show()
# Out:
# +-------+------------------------------------+---------+-----------------------------------+--------------------------+
# |summary|                               about|       id|                               name|             prerequisites|
# +-------+------------------------------------+---------+-----------------------------------+--------------------------+
# |  count|                                3779|     3781|                               3781|                      3779|
# |   mean|                1.587301587301592E19|     NULL|                               NULL|                     111.0|
# | stddev|                4.199605255658078E19|     NULL|                               NULL|                      NULL|
# |    min|                                    |C_1017355|                    Food Chemistry |                          |
# |    max|（1）特色：课程资源建设，充分体现...| C_956450|（疾风计划）面向对象程序设计（C++）|高级语言程序设计、数据结构|
# +-------+------------------------------------+---------+-----------------------------------+--------------------------+

# %%
course_df.select('id').show(truncate=False)
# Out:
# +--------+
# |id      |
# +--------+
# |C_584313|
# |C_584329|
# |C_584381|
# |C_597208|
# |C_597225|
# |C_597229|
# |C_597291|
# |C_597307|
# |C_597365|
# |C_597367|
# |C_645178|
# |C_608132|
# |C_678165|
# |C_629513|
# |C_629514|
# |C_629515|
# |C_629520|
# |C_629522|
# |C_654397|
# |C_654551|
# +--------+
# only showing top 20 rows

# %% [markdown]
# ## course-field

# %%
course_field_df = spark.read.json("/content/drive/MyDrive/Big Data/Input/course-field.json")

# %%
course_field_df.describe().show()
# Out:
# +-------+-----------------+------------------+
# |summary|        course_id|       course_name|
# +-------+-----------------+------------------+
# |  count|              632|               632|
# |   mean|691117.9841772151|              NULL|
# | stddev| 84019.2774572239|              NULL|
# |    min|           584313|      5G与人工智能|
# |    max|          1814513|麦肯锡“全球领导力”|
# +-------+-----------------+------------------+

# %%
course_field_df.show(truncate=False)
# Out:
# +---------+-----------------------------------+----------------------+
# |course_id|course_name                        |field                 |
# +---------+-----------------------------------+----------------------+
# |584313   |《资治通鉴》导读                   |[中国语言文学, 历史学]|
# |681932   |“做中学”Java程序设计               |[计算机科学与技术]    |
# |674962   |《红楼梦》的空间艺术               |[中国语言文学]        |
# |682709   |《纯粹理性批判》导论               |[哲学]                |
# |682635   |《统万城》导读                     |[历史学]              |
# |629515   |《论语》人生课堂                   |[中国语言文学]        |
# |681692   |5G与人工智能                       |[计算机科学与技术]    |
# |697791   |C++语言程序设计基础                |[计算机科学与技术]    |
# |676937   |C++语言程序设计进阶                |[计算机科学与技术]    |
# |682131   |C君带你玩编程                      |[计算机科学与技术]    |
# |784172   |C语言程序设计（上）                |[计算机科学与技术]    |
# |682672   |C语言程序设计（下）                |[计算机科学与技术]    |
# |677038   |e时代的大佬师——慕课教师的修炼心法  |[教育学]              |
# |677045   |e时代的教与学——慕课引发的混合式教学|[教育学]              |
# |677235   |e时代的新课堂——在线教育概论        |[教育学]              |
# |682181   |Grasshopper参数化设计与建模        |[新闻传播学]          |
# |674942   |Hello,心理学                       |[心理学]              |
# |681786   |IC设计与方法                       |[电子科学与技术]      |
# |677010   |Java程序设计                       |[计算机科学与技术]    |
# |682759   |JAVA程序设计进阶                   |[计算机科学与技术]    |
# +---------+-----------------------------------+----------------------+
# only showing top 20 rows

# %%
course_field_df.printSchema()
# Out:
# root
#  |-- course_id: long (nullable = true)
#  |-- course_name: string (nullable = true)
#  |-- field: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
print(course_field_df.count())
# Out:
# 632

# %%
null_counts = course_field_df.select([
    sum(when(col(c).isNull(), 1).otherwise(0)).alias(c)
    for c in course_field_df.columns
])

null_counts.show()
# Out:
# +---------+-----------+-----+
# |course_id|course_name|field|
# +---------+-----------+-----+
# |        0|          0|    0|
# +---------+-----------+-----+

# %%
from pyspark.sql.functions import concat, lit, col

course_field_df = course_field_df.withColumn(
    "course_id",
    concat(lit("C_"), col("course_id").cast("string"))
)

# Kiểm tra lại
course_field_df.show(truncate=False)
# Out:
# +---------+-----------------------------------+----------------------+
# |course_id|course_name                        |field                 |
# +---------+-----------------------------------+----------------------+
# |C_584313 |《资治通鉴》导读                   |[中国语言文学, 历史学]|
# |C_681932 |“做中学”Java程序设计               |[计算机科学与技术]    |
# |C_674962 |《红楼梦》的空间艺术               |[中国语言文学]        |
# |C_682709 |《纯粹理性批判》导论               |[哲学]                |
# |C_682635 |《统万城》导读                     |[历史学]              |
# |C_629515 |《论语》人生课堂                   |[中国语言文学]        |
# |C_681692 |5G与人工智能                       |[计算机科学与技术]    |
# |C_697791 |C++语言程序设计基础                |[计算机科学与技术]    |
# |C_676937 |C++语言程序设计进阶                |[计算机科学与技术]    |
# |C_682131 |C君带你玩编程                      |[计算机科学与技术]    |
# |C_784172 |C语言程序设计（上）                |[计算机科学与技术]    |
# |C_682672 |C语言程序设计（下）                |[计算机科学与技术]    |
# |C_677038 |e时代的大佬师——慕课教师的修炼心法  |[教育学]              |
# |C_677045 |e时代的教与学——慕课引发的混合式教学|[教育学]              |
# |C_677235 |e时代的新课堂——在线教育概论        |[教育学]              |
# |C_682181 |Grasshopper参数化设计与建模        |[新闻传播学]          |
# |C_674942 |Hello,心理学                       |[心理学]              |
# |C_681786 |IC设计与方法                       |[电子科学与技术]      |
# |C_677010 |Java程序设计                       |[计算机科学与技术]    |
# |C_682759 |JAVA程序设计进阶                   |[计算机科学与技术]    |
# +---------+-----------------------------------+----------------------+
# only showing top 20 rows

# %% [markdown]
# ## Join

# %%
valid_course_field_df = course_field_df.join(
    course_df,
    course_field_df.course_id == course_df.id,
    "inner"
).select(
    course_field_df.course_id,
    course_field_df.course_name,
    course_field_df.field
)

# %%
valid_course_field_df.show()
# Out:
# +---------+---------------------------------+--------------------------------+
# |course_id|                      course_name|                           field|
# +---------+---------------------------------+--------------------------------+
# | C_584313|                 《资治通鉴》导读|          [中国语言文学, 历史学]|
# | C_584329|       微积分——极限理论与一元函数|[应用经济学, 理论经济学, 物理...|
# | C_584381|                         新闻摄影|            [新闻传播学, 艺术学]|
# | C_597208|             数据挖掘：理论与算法|              [计算机科学与技术]|
# | C_597229|                   财务分析与决策|    [应用经济学, 管理科学与工程]|
# | C_597307|                         大唐兴衰|                        [历史学]|
# | C_629515|                 《论语》人生课堂|                  [中国语言文学]|
# | C_629520|                       病理生理学|                      [临床医学]|
# | C_629522|                     医学文献检索|                    [科学技术史]|
# | C_629503|信息素养——学术研究的必修课（20...|                [情报与档案管理]|
# | C_597314|     大学国文——北宋至现代文学赏析|                  [中国语言文学]|
# | C_674903|       不朽的艺术：走进大师与经典|                        [艺术学]|
# | C_674920|                       逻辑学概论|                          [哲学]|
# | C_674921|                       管理学原理|                [管理科学与工程]|
# | C_674926|             揭开潜意识心理的奥秘|                        [心理学]|
# | C_674942|                     Hello,心理学|                        [心理学]|
# | C_674948|                     企业战略管理|                [管理科学与工程]|
# | C_674950|               经济地理与企业兴衰|                        [地理学]|
# | C_674962|             《红楼梦》的空间艺术|                  [中国语言文学]|
# | C_674968|                         巴蜀文化|          [民族学, 中国语言文学]|
# +---------+---------------------------------+--------------------------------+
# only showing top 20 rows

# %%
print("Số lượng dòng dữ liệu hợp lệ:", valid_course_field_df.count())
print("Số lượng dòng dữ liệu không hợp lệ:", course_field_df.count() - valid_course_field_df.count())
# Out:
# Số lượng dòng dữ liệu hợp lệ: 547
# Số lượng dòng dữ liệu không hợp lệ: 85

# %%
# Đọc các file CSV mapping
course_mapping_df = spark.read.option("header", "true").csv("/content/drive/MyDrive/Big Data/Output/course_mapping.csv")

print("Course Mapping:")
course_mapping_df.show(10)
# Out:
# Course Mapping:
# +-----------+---------+
# |original_id|mapped_id|
# +-----------+---------+
# |  C_1017355|        0|
# |  C_1017419|        1|
# |  C_1025064|        2|
# |  C_1025076|        3|
# |  C_1025079|        4|
# |  C_1073350|        5|
# |  C_1123814|        6|
# |  C_1123848|        7|
# |  C_1123944|        8|
# |  C_1123979|        9|
# +-----------+---------+
# only showing top 10 rows

# %%
course_field_mapped_df = valid_course_field_df.join(
    course_mapping_df,
    valid_course_field_df.course_id == course_mapping_df.original_id,
    "inner"
).select(
    course_mapping_df.mapped_id.alias("mapped_course_id"),
    valid_course_field_df.course_name,
    valid_course_field_df.field
)

# %%
course_field_mapped_df.show(truncate=False)
# Out:
# +----------------+------------------------------------+--------------------------------------------+
# |mapped_course_id|course_name                         |field                                       |
# +----------------+------------------------------------+--------------------------------------------+
# |1158            |微积分——极限理论与一元函数          |[应用经济学, 理论经济学, 物理学, 数学]      |
# |1159            |新闻摄影                            |[新闻传播学, 艺术学]                        |
# |1160            |数据挖掘：理论与算法                |[计算机科学与技术]                          |
# |1162            |财务分析与决策                      |[应用经济学, 管理科学与工程]                |
# |1164            |信息素养——学术研究的必修课（2019春）|[情报与档案管理]                            |
# |1163            |大学国文——北宋至现代文学赏析        |[中国语言文学]                              |
# |1173            |不朽的艺术：走进大师与经典          |[艺术学]                                    |
# |1177            |逻辑学概论                          |[哲学]                                      |
# |1182            |经济地理与企业兴衰                  |[地理学]                                    |
# |1186            |《红楼梦》的空间艺术                |[中国语言文学]                              |
# |1187            |巴蜀文化                            |[民族学, 中国语言文学]                      |
# |1190            |创办新企业                          |[工商管理]                                  |
# |1191            |创新创业心理学                      |[心理学]                                    |
# |1195            |儒家修身之道                        |[中国语言文学]                              |
# |1200            |党的十九大精神概论                  |[军队政治工作学, 军事思想及军事历史, 政治学]|
# |1201            |审美的历程                          |[哲学]                                      |
# |1204            |生活、艺术与时尚：中国服饰七千年    |[艺术学]                                    |
# |1212            |积极心理学（下）自强不息篇          |[心理学]                                    |
# |1215            |经典与思考——人文清华大师面对面      |[教育学]                                    |
# |1216            |决胜移动互联网：创业者的商业模式课  |[工商管理]                                  |
# +----------------+------------------------------------+--------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## tạo field riêng

# %%
field_df = (
    course_field_mapped_df
    .select(explode(col("field")).alias("name"))
    .distinct()
    .withColumn("field_id", monotonically_increasing_id() + 13023)
)

# %%
field_df.show(truncate=False)
# Out:
# +--------------------+--------+
# |name                |field_id|
# +--------------------+--------+
# |哲学                |13023   |
# |公共管理            |13024   |
# |畜牧学              |13025   |
# |口腔医学            |13026   |
# |兵器科学与技术      |13027   |
# |计算机科学与技术    |13028   |
# |动力工程及工程热物理|13029   |
# |控制科学与工程      |13030   |
# |园艺学              |13031   |
# |地质学              |13032   |
# |临床中医学          |13033   |
# |植物保护            |13034   |
# |化学工程与技术      |13035   |
# |仪器科学与技术      |13036   |
# |地球物理学          |13037   |
# |生物医学工程        |13038   |
# |体育学              |13039   |
# |土木工程            |13040   |
# |心理学              |13041   |
# |材料科学与工程      |13042   |
# +--------------------+--------+
# only showing top 20 rows

# %%
# 3. Tạo bảng Course_Field: explode mảng field rồi join để lấy field_id
course_field_mapped_df = (
    course_field_mapped_df
    .select("mapped_course_id", explode(col("field")).alias("name"))
    .join(field_df, on="name", how="inner")
    .select("mapped_course_id", "field_id")
)

# %%
course_field_mapped_df.show(truncate=False)
# Out:
# +----------------+--------+
# |mapped_course_id|field_id|
# +----------------+--------+
# |2491            |13023   |
# |1925            |13023   |
# |1924            |13023   |
# |1768            |13023   |
# |1419            |13023   |
# |1408            |13023   |
# |1287            |13023   |
# |1232            |13023   |
# |1201            |13023   |
# |1177            |13023   |
# |1270            |13024   |
# |2085            |13024   |
# |1434            |13024   |
# |1961            |13024   |
# |1489            |13024   |
# |2018            |13025   |
# |1391            |13026   |
# |1757            |13026   |
# |2052            |13027   |
# |2341            |13028   |
# +----------------+--------+
# only showing top 20 rows

# %%
# Bước 3: Tạo chuỗi text theo format yêu cầu: course_id 0 teacher_id (0 là mối quan hệ teacher)
output_df = course_field_mapped_df.select(
    concat_ws(" ",
        col("mapped_course_id"),
              lit(1),
        col("field_id")
    ).alias("output_line")
)

# %%
output_df.show(truncate=False)
# Out:
# +------------+
# |output_line |
# +------------+
# |2491 1 13023|
# |1925 1 13023|
# |1924 1 13023|
# |1768 1 13023|
# |1419 1 13023|
# |1408 1 13023|
# |1287 1 13023|
# |1232 1 13023|
# |1201 1 13023|
# |1177 1 13023|
# |1270 1 13024|
# |2085 1 13024|
# |1434 1 13024|
# |1961 1 13024|
# |1489 1 13024|
# |2018 1 13025|
# |1391 1 13026|
# |1757 1 13026|
# |2052 1 13027|
# |2341 1 13028|
# +------------+
# only showing top 20 rows

# %%
print(course_field_mapped_df.count())
# Out:
# 576

# %%
# Save as a single .txt file
output_df.coalesce(1).write \
    .mode("overwrite") \
    .text("output/course_field_mapping.txt")

# %%
# prompt: save lại field_df theo định dạng json
field_df.coalesce(1).write.mode("overwrite").json("output/field_df_json")
